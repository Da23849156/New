# %%
import numpy as np
from skimage import data
import matplotlib.pyplot as plt 
# %matplotlib inline
    
image = data.camera()

# %%
plt.imshow(image,cmap='gray')

# %%
type(image)
# Out:
# numpy.ndarray

# %%
mask=image<40
image[mask]=255
plt.imshow(image, cmap='gray')

# %% [markdown]
# **mask 程度較小**

# %%
mask=image<10
image[mask]=255
plt.imshow(image, cmap='gray')

# %% [markdown]
# **mask程度較大**

# %%
mask=image<120
image[mask]=255
plt.imshow(image, cmap='gray')
