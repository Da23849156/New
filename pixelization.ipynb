# %%
from PIL import Image
import cv2

# %%
pic=Image.open('david.jpg')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2048x1365 at 0x1192F3FD0>

# %%
imgSmall = pic.resize((32,32),resample=Image.BILINEAR)

# %%
result = imgSmall.resize(pic.size,Image.NEAREST)

# %%
result
# Out:
# <PIL.Image.Image image mode=RGB size=2048x1365 at 0x1192F8F90>
